# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi-216/Python/blob/main/Practical_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ecom = pd.read_csv('E-Commerce.csv')

# %%
ecom[:5] #ecom.head(5)
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  Order_Date
# 0         1       Laptop  Electronics   1200         2        C101  01-01-2024
# 1         2   Headphones  Electronics     80         3        C102  02-01-2024
# 2         3        Chair    Furniture    150         1        C103  03-01-2024
# 3         4   Smartphone  Electronics    600         1        C104  04-01-2024
# 4         5         Desk    Furniture    200         2        C105  05-01-2024

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      30 non-null     int64
#  1   Product_Name  30 non-null     object
#  2   Category      30 non-null     object
#  3   Price         30 non-null     int64
#  4   Quantity      30 non-null     int64
#  5   Customer_ID   30 non-null     object
#  6   Order_Date    30 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 1.8+ KB

# %%
ecom.columns
# Out:
# Index(['Order_ID', 'Product_Name', 'Category', 'Price', 'Quantity',
#        'Customer_ID', 'Order_Date'],
#       dtype='object')

# %%
ecom.isnull().sum()
# Out:
# Order_ID        0
# Product_Name    0
# Category        0
# Price           0
# Quantity        0
# Customer_ID     0
# Order_Date      0
# dtype: int64

# %%
ecom['Category'].unique()
# Out:
# array(['Electronics', 'Furniture', 'Apparel', 'Books', 'Accessories',
#        'Beauty'], dtype=object)

# %%
ecom['Quantity'].sum()
# Out:
# 61

# %%
c=ecom.groupby('Category')['Price'].mean()
cd=c.reset_index()
cd.columns=['Category','AvgPrice']
cd
# Out:
#       Category    AvgPrice
# 0  Accessories   82.500000
# 1      Apparel   37.500000
# 2       Beauty   27.500000
# 3        Books   17.500000
# 4  Electronics  420.000000
# 5    Furniture  196.666667

# %%
ecom[ecom['Price']==max(ecom['Price'])]
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0         1       Laptop  Electronics   1200         2        C101
#
#    Order_Date  Total_Purchase
# 0  01-01-2024            2400

# %%
ecom.loc[ecom['Price'].idxmax()]
# Out:
# Order_ID                  1
# Product_Name         Laptop
# Category        Electronics
# Price                  1200
# Quantity                  2
# Customer_ID            C101
# Order_Date       01-01-2024
# Name: 0, dtype: object

# %%
dic={}
ecom['Total_Purchase']=ecom['Quantity']*ecom['Price']
name=ecom.groupby('Customer_ID')['Total_Purchase'].sum().idxmax()
maxi=ecom['Total_Purchase'].max()
dic[name]=maxi #doubt
dic
# Out:
# {'C101': 2400}

# %%
ecom['Total_Purchase'].sum()
# Out:
# 8615

# %%
#Products ordered on 2024-01-05

# %%
ecom['Total_Purchase']=ecom['Quantity']*ecom['Price']
name=ecom.groupby('Customer_ID')['Total_Purchase'].sum()
name.sort_values(ascending=False).head(3)

#ecom.groupby('Customer_ID')['Total_Purchase'].sum().nlargest(3)
# Out:
# Customer_ID
# C101    2710
# C113    1690
# C104     600
# Name: Total_Purchase, dtype: int64

# %%
ecom.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Accessories     6
# Apparel        20
# Beauty          7
# Books           5
# Electronics    16
# Furniture       7
# Name: Quantity, dtype: int64

# %%
ecom['Quantity'].mean()
# Out:
# 2.033333333333333

# %%
ecom[ecom["Price"]<50][['Order_ID','Product_Name','Price']]
# Out:
#     Order_ID Product_Name  Price
# 5          6        Shirt     30
# 8          9         Book     15
# 13        14        Jeans     40
# 15        16      Perfume     25
# 20        21        Shirt     25
# 21        22         Book     20
# 23        24        Shoes     45
# 27        28        Jeans     35
# 29        30      Perfume     30

# %%
ecom[ecom["Quantity"]==max(ecom['Quantity'])]
# Out:
#    Order_ID Product_Name Category  Price  Quantity Customer_ID  Order_Date  \
# 5         6        Shirt  Apparel     30         5        C106  06-01-2024
#
#    Total_Purchase
# 5             150

# %%
ecom[ecom['Customer_ID']=="C10"]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Product_Name, Category, Price, Quantity, Customer_ID, Order_Date, Total_Purchase]
# Index: []

# %%
Total_Purchase= ecom['Quantity']*ecom['Price']
ecom.groupby('Category')[['Quantity','Total_Purchase']].sum('Total_Purchase')
# Out:
#              Quantity  Total_Purchase
# Category
# Accessories         6             440
# Apparel            20             700
# Beauty              7             190
# Books               5              85
# Electronics        16            5820
# Furniture           7            1380

# %%
ecom.groupby('Product_Name')[['Product_Name']].filter(lambda x: x.value_counts()==1)
# Out:
#    Product_Name
# 0        Laptop
# 3    Smartphone
# 6        Tablet
# 11     Backpack
# 16      Speaker
# 17   Sunglasses
# 18        Table

# %%
electro=pd.DataFrame(ecom[ecom["Category"]=='Electronics'])
electro
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0          1       Laptop  Electronics   1200         2        C101
# 1          2   Headphones  Electronics     80         3        C102
# 3          4   Smartphone  Electronics    600         1        C104
# 6          7       Tablet  Electronics    300         1        C107
# 12        13       Camera  Electronics    800         1        C113
# 14        15      Printer  Electronics    150         1        C115
# 16        17      Speaker  Electronics    120         2        C108
# 19        20   Headphones  Electronics     70         3        C101
# 26        27       Camera  Electronics    750         1        C113
# 28        29      Printer  Electronics    130         1        C105
#
#     Order_Date  Total_Purchase
# 0   01-01-2024            2400
# 1   02-01-2024             240
# 3   04-01-2024             600
# 6   07-01-2024             300
# 12  13-01-2024             800
# ...

# %%
ecom.groupby('Order_Date')['Quantity'].sum().idxmax()
# Out:
# '06-01-2024'

# %%
ecom[ecom['Price']%2==0]
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0          1       Laptop  Electronics   1200         2        C101
# 1          2   Headphones  Electronics     80         3        C102
# 2          3        Chair    Furniture    150         1        C103
# 3          4   Smartphone  Electronics    600         1        C104
# 4          5         Desk    Furniture    200         2        C105
# 5          6        Shirt      Apparel     30         5        C106
# 6          7       Tablet  Electronics    300         1        C107
# 7          8        Shoes      Apparel     50         2        C108
# 9         10         Desk    Furniture    180         1        C110
# 10        11        Watch  Accessories    100         1        C111
# 11        12     Backpack  Accessories     50         2        C112
# 12        13       Camera  Electronics    800         1        C113
# 13        14        Jeans      Apparel     40         3        C114
# ...

# %%
ecom.groupby('Category')['Total_Purchase'].sum()*100/ecom['Total_Purchase'].sum()
# Out:
# Category
# Accessories     5.107371
# Apparel         8.125363
# Beauty          2.205456
# Books           0.986651
# Electronics    67.556587
# Furniture      16.018572
# Name: Total_Purchase, dtype: float64
